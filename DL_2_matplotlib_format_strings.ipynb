# %%
import matplotlib.pyplot as plt #visualization library

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weekly Weather')
# plt.plot(x,y,'--')
plt.plot(x,y,color="blue",marker="*",markerstyle="dashdot")
